# %%
# %run REINFORCE.ipynb
network_action = REINFORCEloop(epochs)


sess = tf.Session()
saver = tf.train.Saver()
saver.save(sess, 'my_test_model',global_step=1000)


#network_value = Valueloop(epochs)
# Out:
# [0]
# boardscore
# Not finished Game
# [6]
# boardscore
# Not finished Game
# [0]
# boardscore
# Not finished Game
# [6]
# boardscore
# Not finished Game
# [0]
# boardscore
# Not finished Game
# [5]
# boardscore
# Not finished Game
# [0]
# boardscore
# Not finished Game
# one_loop_done
# [0]
# boardscore
# Not finished Game
# [1]
# boardscore
# Not finished Game
# [5]
# boardscore
# Not finished Game
# [1]
# boardscore
# Not finished Game
# [2]
# boardscore
# Not finished Game
# [4]
# boardscore
# Not finished Game
# [1]
# boardscore
# Not finished Game
# [5]
# boardscore
# Not finished Game
# [2]
# boardscore
# Not finished Game
# [0]
# boardscore
# Not finished Game
# [0]
# boardscore
# Not finished Game
# [4]
# boardscore
# Not finished Game
# [4]
# boardscore
# Not finished Game
# [5]
# boardscore
# Not finished Game
# [1]
# boardscore
# Not finished Game
# [4]
# boardscore
# Not finished Game
# [0]
# boardscore
# Not finished Game
# [5]
# boardscore
# Not finished Game
# [0]
# ...
